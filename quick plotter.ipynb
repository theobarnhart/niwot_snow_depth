# %%
import glob as glob

# %%
fl = '/Volumes/hydroProjects/Data/FieldData/pingersites/CZO/jemez/data/wy2017/*.dat'
title = 'Vcm Snow Depth Sensors'

# %%
fls = glob.glob(fl)

# %%
fl = fls[0]

# %%
header = list(pd.read_table(fl,sep=',',skiprows=1).columns)

# %%
tmp = pd.read_table(fl,sep=',',skiprows=4,header=None,names=header)
tmp.index = pd.DatetimeIndex(tmp.TIMESTAMP)

# %%
tmp.shape
# Out:
# (622, 43)

# %%
dat = pd.DataFrame(columns=header)
for fl in fls:
    tmp = pd.read_table(fl,sep=',',skiprows=4,header=None,names=header)
    tmp.index = pd.DatetimeIndex(tmp.TIMESTAMP)
    
    dat = dat.append(tmp)

dat.drop_duplicates(inplace=True)

# %%
depths = tmp.filter(regex='DSDepth_*')

# %%
depths.plot(figsize=(15,5))
plt.ylabel('Snow Depth [cm]', fontsize = 16)
plt.title(title,fontsize=20)

# %%
dat.index.max()
# Out:
# Timestamp('2016-12-08 01:00:00')
