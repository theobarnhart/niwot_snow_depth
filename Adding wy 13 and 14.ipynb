# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab
# %matplotlib inline

pylab.rcParams['figure.figsize'] = (16.0, 8.0)

# %%
sd = pd.DataFrame({'depth':pd.read_pickle('../../data/AMS_L2_WY_2006_2012_clean_ave.pcl')})

# %%
plt.plot(sd.index,sd);

# %%
sd13 = pd.read_pickle('../../data/AMS_wy2013_clean_ave.pcl')
sd14 = pd.DataFrame({'depth':pd.read_pickle('../../data/AMS_wy_2014_clean_mean_tbb.pcl')})

# %%
sd = pd.concat([sd,sd13,sd14])

# %%
plt.plot(sd.index, sd)

# %%
sd.to_pickle('../../data/AMS_wy2006_2014_ave.pcl')
